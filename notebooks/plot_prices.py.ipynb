# %%
from contextlib import closing
import argparse
from IPython.display import display, HTML
from tinyman.v1.client import TinymanMainnetClient
import pandas as pd
from matplotlib import pyplot as plt
from algo.blockchain.process_prices import PriceScraper
from algo.blockchain.utils import generator_to_df
import datetime

display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
client = TinymanMainnetClient()
ps = PriceScraper(client, 0, 470842789)

# %%
df = generator_to_df(ps.query_pool_state_history(10))

# %%
plt.plot(df['time'], df['asset1_reserves']/df['asset2_reserves'])
plt.grid()
